# %% [markdown]
# Use this notebook to try out some experimental changes. Currently, this notebooks runs a state from ${COMMIT_TIMESTAMP} about which the author said:
# ```
# ${COMMIT_MESSAGE}
# ```
# The system might need a few hours to build the next version. You can check the state of the latest build here: <a href="${CI_URL}"><img style="display: inline" src="${CI_BADGE}"></a>
# You can reload this notebook with the latest version anytime by clicking here: <a href="${BINDER_URL}"><img style="display: inline" src="https://camo.githubusercontent.com/d57df63fab21897847014ebaec3e7f5f48951ad2/68747470733a2f2f626574612e6d7962696e6465722e6f72672f62616467652e737667"></a> (changes are not preserved.)

# %%
1 + 1
